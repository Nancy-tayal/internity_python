# %% [markdown]
# # Regression
# Regression analysis is a form of predictive modelling technique which investigates the relationship between a dependent and independent variable. Regression is mostly used for forecasting and finding out cause and effect of relationship between variables. Regression techniques mostly differ based on the number of independent variables and the type of relationship between the independent and dependent variables.
#
# The dependent features are called the dependent variables, outputs, or responses.
#
# The independent features are called the independent variables, inputs, or predictors.
#
# Regression problems usually have one continuous and unbounded dependent variable. The inputs, however, can be continuous, discrete, or even categorical data such as gender, nationality, brand, and so on.
#
# Regression analysis is used for three types of applications:
#
# * Finding out the effect of Input variables on Target variable.
# * Finding out the change in Target variable with respect to one or more input variable.
# * To find out upcoming trends.
#
# **Types of Regression**
#
# * Linear Regression
# * Logistic Regression
# * Polynomial Regression
# * Stepwise Regression
#
# # Linear Regression
# Linear Regression is a machine learning algorithm based on supervised learning. Linear regression may be defined as the statistical model that analyzes the linear relationship between a dependent variable with given set of independent variables. Linear relationship between variables means that when the value of one or more independent variables will change (increase or decrease), the value of dependent variable will also change accordingly (increase or decrease).
#
# Mathematically the relationship can be represented with the help of following equation −
#
# Y = mX + b
#
# Here, Y is the dependent variable we are trying to predict
#
# X is the independent variable we are using to make predictions.
#
# m is the slope of the regression line which represents the effect X has on Y
#
# b is a constant, known as the Y-intercept. If X = 0,Y would be equal to b.
#
# **Furthermore, the linear relationship can be positive or negative in nature.**
# * Positive Linear Relationship - A linear relationship will be called positive if both independent and dependent variable increases.
# * Negative Linear relationship - A linear relationship will be called positive if independent increases and dependent variable decreases.
#
# **Applications of Linear Regression**
# * Prediction of trends and Sales targets - To predict how industry is performing or how many sales targets industry may achieve in the future.
# * Price Prediction - Using regression to predict the change in price of stock or product.
# * Risk Management - Using regression to the analysis of Risk Management in the financial and insurance sector.
#
# **Types of Linear Regression**
# Linear regression is of the following two types −
# * Simple Linear Regression
# * Multiple Linear Regression
#
# **To create our model, we must “learn” or estimate the values of regression coefficients b_0 and b_1. And once we’ve estimated these coefficients, we can use the model to predict responses!**
#
# # Least Square Method – Finding the best fit line
# Least squares is a statistical method used to determine the best fit line or the regression line by minimizing the sum of squares created by a mathematical function. The “square” here refers to squaring the distance between a data point and the regression line. The line with the minimum value of the sum of square is the best-fit regression line.
# Regression Line, y = mx+c where,
#
# y = Dependent Variable
#
# x= Independent Variable ; c = y-Intercept
#
# ![image.png](attachment:image.png)
#
# **R Square Method – Goodness of Fit**
#
# R–squared value is the statistical measure to show how close the data are to the fitted regression line.
#
#
#
#
# y = actual value
#
# y ̅ = mean value of y
#
# yp =  predicted value of y
#
# ![image-2.png](attachment:image-2.png)
# R-squared does not indicate whether a regression model is adequate. You can have a low R-squared value for a good model, or a high R-squared value for a model that does not fit the data!
#
# **Simple linear regression** is an approach for predicting a response using a single feature.It is assumed that the two variables are linearly related.

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
 
# Reading Data
df = pd.read_csv('test.csv')
print(df.shape)
print(df.head())
# Collecting X and Y
X = data['x'][0:100].values
Y = data['y'][0:100].values

# Mean X and Y
mean_x = np.mean(X)
mean_y = np.mean(Y)
 
# Total number of values
n = len(X)
print("Length of the input:",np.size(X))
 
# Using the formula to calculate m and c
numer = np.sum((X-mean_x)*(Y - mean_y))
denom = np.sum((X - mean_x)**2)
m = numer / denom
c = mean_y - (m * mean_x)
 
# Print coefficients
print("b0:", c, "b1:",m)

# Plotting Values and Regression Line
max_x = np.max(X) + 100
min_x = np.min(X) - 100
# Calculating line values x and y
x = np.linspace(min_x, max_x, 1000)
y = c + m * x   # Estimated values
 
# Ploting Line
plt.plot(x, y, 'g', label='Regression Line')
# Ploting Scatter Points
plt.scatter(X, Y, c='r', label='Scatter Plot')
 
plt.xlabel('X')
plt.ylabel('Y')
plt.legend()
plt.show()



#ss_t is the total sum of squares and ss_r is the total sum of squares of residuals(relate them to the formula).
y_pred = c + (m * X)
ss_t = np.sum((Y - mean_y) ** 2)
ss_r = np.sum((Y - y_pred) ** 2)
r2 = 1 - (ss_r/ss_t)
print("R-squared:",r2)
# Out:
# (300, 2)
#     x          y
# 0  77  79.775152
# 1  21  23.177279
# 2  22  25.609262
# 3  20  17.857388
# 4  36  41.849864
# Length of the input: 100
# b0: 0.02560561864645905 b1: 1.0022215372695817
# R-squared: 0.9877266894153498

# %%
# unsing cross Deviation and deviation about x
def estimate_coef(x, y):
    # number of observations/points
    n = np.size(x)

    # mean of x and y vector
    mean_x = np.mean(x)
    mean_y = np.mean(y)
    # calculating cross-deviation and deviation about x
    SS_xy = np.sum(y*x) - n*mean_y*mean_x
    SS_xx = np.sum(x*x) - n*mean_x*mean_x

    # calculating regression coefficients
    b_1 = SS_xy / SS_xx
    b_0 = mean_y - b_1*mean_x

    return (b_0, b_1)

def plot_regression_line(x, y, b):
    # plotting the actual points as scatter plot
    plt.scatter(x, y, color ="r")

    # predicted response vector
    y_pred = b[0] + b[1]*x

    # plotting the regression line
    plt.plot(x, y_pred, 'g')

    # putting labels
    plt.xlabel('x')
    plt.ylabel('y')

    # function to show plot
    plt.show()

def R_squared(c,m, X,Y):
    mean_y = np.mean(Y)
    y_pred = c + (m * X)
    ss_t = np.sum((Y - mean_y) ** 2)
    ss_r = np.sum((Y - y_pred) ** 2)
    r2 = 1 - (ss_r/ss_t)
    print("R-squared:",r2)

def main():
    # observations / data
    x = df["x"][100:300].values
    y = df["y"][100:300].values

    # estimating coefficients
    b = estimate_coef(x, y)
    print("Estimated coefficients:\nb0 = {} \
        \nb1 = {}".format(b[0], b[1]))

    # plotting regression line
    plot_regression_line(x, y, b)
    R_squared(b[0],b[1],x, y)

if __name__ == "__main__":
    main()
# Out:
# Estimated coefficients:
# b0 = -0.6563722357427935
# b1 = 1.019567594048447
# R-squared: 0.9897891281499981
